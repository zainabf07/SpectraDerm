# %% [markdown]
# # Module AH — OTC Skincare Catalog
#
# Synthetic catalog queries only. AH is read-only brand-neutral knowledge; it does not invoke AB or any other agent.

# %%
from spectraderm.catalog.otc_catalog import get_categories_for_pattern, get_category, list_categories

# %% [markdown]
# ## All controlled categories

# %%
list_categories()
get_category('pigment_correctors')

# %% [markdown]
# ## Controlled relevance metadata
#
# These results are catalog metadata only, not diagnoses or recommendations.

# %%
get_categories_for_pattern('pigmentation')
get_categories_for_pattern('redness_irritation')
get_categories_for_pattern('acne_like_texture')
get_categories_for_pattern('dryness_barrier')

# %% [markdown]
# ## Unknown pattern
#
# Unknown intentionally returns no targeted skincare categories.

# %%
get_categories_for_pattern('unknown')
