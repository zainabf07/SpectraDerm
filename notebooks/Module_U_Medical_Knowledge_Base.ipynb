# %% [markdown]
# # Module U: Curated Medical Knowledge Base
# This is a source-catalog and chunking demonstration for evidence context. It is not diagnosis or clinical validation.

# %%
from spectraderm.rag.knowledge_base import build_chunks, load_sources

sources = load_sources()
for source in sources:
    print(source.source_id, '-', source.organization, '-', source.url)

# %%
chunks = build_chunks()
print('Sources:', len(sources))
print('Chunks:', len(chunks))
print(chunks[0])
